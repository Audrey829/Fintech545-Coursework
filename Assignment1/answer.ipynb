# %% [markdown]
# $$ Problem 1 $$

# %%
\[
\hat{\mu}=0.001104,
\]

\[
\hat{\sigma}^2=0.000096,
\]

\[
\widehat{\text{Skewness}}=-0.669837,
\]

and

\[
\widehat{\text{Excess Kurtosis}}=2.357614.
\]
# Out:
#   Cell In[1], line 1
#     \[
#      ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# \subsection*{1(a) Prediction from Sample Moments}
#
# The sample contains 1,000 observations. The first four sample moments are
#
#
# The negative skewness indicates that the distribution is left-skewed, while
# the positive excess kurtosis indicates heavier tails than a Normal
# distribution.
#
# A Normal distribution is ruled out because it requires both zero skewness
# and zero excess kurtosis. A Lognormal distribution is ruled out by the
# negative skewness, since a Lognormal distribution must be positively skewed.
# A Student's $t$ distribution can account for the positive excess kurtosis,
# but it is symmetric and therefore has zero skewness, so it cannot account
# for the observed negative skewness.
#
# A negatively skewed Normal Inverse Gaussian (NIG) distribution is plausible
# because the NIG family allows both nonzero skewness and positive excess
# kurtosis.
